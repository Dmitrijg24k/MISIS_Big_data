# %% [markdown]
# # Занятие 1

# %% [markdown]
# 1. Немного про наш семестр
# 2. Связные списки
# 3. Pandas. Часть 0. Знакомство с библиотекой. ipython tips.

# %% [markdown]
# # Связные списки

# %% [markdown]
# Ещё классы можно использовать, если вам захочется написать какую-то свою структуру данных. Например, связный список. Это базовый примитив в программировании, которые часто любят использовать для демонстрации каких-нибудь алгоритмических задач. Они примечательны тем, что незваисимо от количества элементов в связном списке операция добавления элемента в начало списка всегда выполняется за некоторое (обычно небольшое) константное время

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Проверять содержится ли в нем тот или иной элемент;
# 2. Добавлять узлы в конец;
# 3. Получать значение узла по индексу;
# 4. Удалять узлы.

# %% [markdown]
# Некоторыми преимуществами связного списка являются его прерывистый характер и время чтения, никогда не превышающее O(n). Связанный список не нужно хранить постоянно, потому что он имеет ссылки, встроенные в каждый узел, для расположения следующего по порядку. Если в памяти вашего компьютера мало места, идеально подойдет связанный список, поскольку всю структуру не нужно хранить в одном месте. Это также означает, что чтение связанного списка является линейным, поскольку размер списка приближается к бесконечности.

# %% [markdown]
# Простой пример односвязного списка:

# %% [markdown]
# Односвязный список состоит из нескольких узлов, каждый из которых содержит а) данные и б) ссылку на следующий узел.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Node(object):
    def __init__(self, value=None, next_node=None):
        self.value = value
        self.next = next_node

    def __str__(self):
        return f"[Node with value {self.value}]"


def print_linked_list(head):
    cur = head
    while cur is not None:
        print(cur)
        cur = cur.next

# %%
h, a, b, c, d = Node(1), Node(2), Node(3), Node("Внезапно"), Node(5)

h.next = a
a.next = b
b.next = c
c.next = d

print_linked_list(h)
# Out:
# [Node with value 1]
# [Node with value 2]
# [Node with value 3]
# [Node with value Внезапно]
# [Node with value 5]

# %% [markdown]
# Двухсвязный список

# %% [markdown]
# В двусвязном списке каждый узел содержит данные, ссылку на узел, после него, и ссылку на узел, предшествующий ему.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://coderlessons.com/tutorials/python-technologies/izuchite-strukturu-dannykh-python/python-sviazannye-spiski

# %% [markdown]
# https://github.com/aspittel/coding-cheat-sheets/blob/master/data_structures/linked_lists.md

# %% [markdown]
# # ПАНДЫ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Pandas - Библиотека для анализа данных и манипяций с ними. Во многих местах из себя представляет фортрановские модули, к которым написаны биндинги для питона. Из-за этого работает очень быстро с одной стороны и много чего умеет, с другой. Например:

# %% [markdown]
# Легко умеет обрабатывать случаи когда в исходном файле какая-то ерунда в некоторых ячейках
# Можно сливать данные, перемешивать колонки, вырезать и по-всячески манипуляровать ими
# Очень интуитивна. Когда наловчишься

# %% [markdown]
# ## Data Frame

# %% [markdown]
# Начнём с "табличного" формата. Он в пандас называется Data Frame и это в принципе не обязательно гомогенная структура данных с подписанными осями. На колонках и строчках можно делать массовые операции.

# %%
# Так как постоянно писать пять букв влом, обычно используют
# конструкцию "import as", чтобы писать только две
import pandas as pd

# %% [markdown]
# Дальше нам доступны все функции pandas. У неё, например, есть много способов прочитать данные и загрузить их в датафрейм. Можно читать excel, csv, json и тому подобное. Мы будем рассматривать работу с pandas на примере другого популярного датасета, в котором официант на протяжении нескольких месяцев записывал подробности о тех, кого он обслуживал, и как много ему давали на чай.

# %%
"/data/tips.csv"
# Out:
# '/data/tips.csv'

# %%
df = pd.read_csv("./data/tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df.tail(1)
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 243       18.78  3.0  Female     No  Thur  Dinner     2

# %% [markdown]
# Узнать что там за колонки можно, подсмотрев "что это за оси"

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=244, step=1),
#  Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')]

# %% [markdown]
# Если интересует только индекс, можно посмотреть информацию только про него

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %% [markdown]
# Данные не обязательно должны быть однотипные но когда это так, то pandas догадывается как их хранить. При этом строкоые константы чаще всего хранятся как тип "объект"

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[207], line 1
# ----> 1 df.get_dtype_counts()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype_counts'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.dtypes.value_counts()
# Out:
# object     4
# float64    2
# int64      1
# dtype: int64

# %% [markdown]
# Размеры датасета можно узнать по свойству shape

# %%
df.shape
# Out:
# (244, 7)

# %% [markdown]
# Совсем белково-дружелюбный вариант можно получить из методов describe или info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# Можно выделять отдельные колонки, смотреть на уникальные значения в колонках, сортировать их, и производить над ними всякие математические операцци en masse

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["day"].nunique()
# Out:
# 4

# %%
df["time"].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df.sort_values("tip", ascending=False).head()
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3
# 212       48.33   9.00  Male     No   Sat  Dinner     4
# 23        39.42   7.58  Male     No   Sat  Dinner     4
# 59        48.27   6.73  Male     No   Sat  Dinner     4
# 141       34.30   6.70  Male     No  Thur   Lunch     6

# %%
df.sort_values("total_bill", ascending=False).head()
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3
# 212       48.33   9.00  Male     No  Sat  Dinner     4
# 59        48.27   6.73  Male     No  Sat  Dinner     4
# 156       48.17   5.00  Male     No  Sun  Dinner     6
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3

# %%
df.sort_values(["sex", "time", "tip"], inplace=True)
df.head()
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 111        7.25  1.00  Female     No  Sat  Dinner     1
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 215       12.90  1.10  Female    Yes  Sat  Dinner     2

# %%
df["total_bill"].head()
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 0      16.99
# 215    12.90
# Name: total_bill, dtype: float64

# %%
(df["total_bill"] * 60.4).head()
# Out:
# 67      185.428
# 92      347.300
# 111     437.900
# 0      1026.196
# 215     779.160
# Name: total_bill, dtype: float64

# %%
df["total_bill"].add(100)
df["total_bill"].sub(100)
df["total_bill"].mul(42)
df["total_bill"].div(42)

df["total_bill"].mul(70.4).head()
# Out:
# 67      216.128
# 92      404.800
# 111     510.400
# 0      1196.096
# 215     908.160
# Name: total_bill, dtype: float64

# %% [markdown]
# В качестве индекса можно вместо номера строки использовать одну из колонок. Если у вас данные категорийные и неуникальные, то по такому индексу могут будут доступны сразу несколько записей

# %%
df = pd.read_csv("data/tips.csv", index_col="time")
df.head()
# Out:
#         total_bill   tip     sex smoker  day  size
# time
# Dinner       16.99  1.01  Female     No  Sun     2
# Dinner       10.34  1.66    Male     No  Sun     3
# Dinner       21.01  3.50    Male     No  Sun     3
# Dinner       23.68  3.31    Male     No  Sun     2
# Dinner       24.59  3.61  Female     No  Sun     4

# %%
df.loc["Dinner"].head()
# Out:
#         total_bill   tip     sex smoker  day  size
# time
# Dinner       16.99  1.01  Female     No  Sun     2
# Dinner       10.34  1.66    Male     No  Sun     3
# Dinner       21.01  3.50    Male     No  Sun     3
# Dinner       23.68  3.31    Male     No  Sun     2
# Dinner       24.59  3.61  Female     No  Sun     4

# %%
df.loc["Lunch"].head()
# Out:
#        total_bill   tip   sex smoker   day  size
# time
# Lunch       27.20  4.00  Male     No  Thur     4
# Lunch       22.76  3.00  Male     No  Thur     2
# Lunch       17.29  2.71  Male     No  Thur     2
# Lunch       19.44  3.00  Male    Yes  Thur     2
# Lunch       16.66  3.40  Male     No  Thur     2

# %%
df.index.unique()
# Out:
# Index(['Dinner', 'Lunch'], dtype='object', name='time')

# %%
"Lunch" in df.index
# Out:
# True

# %%
"Breakfast" in df.index
# Out:
# False

# %% [markdown]
# Если очень хочется доступ по номеру записи, то можно сделать iloc

# %%
df.iloc[23]
# Out:
# total_bill    39.42
# tip            7.58
# sex            Male
# smoker           No
# day             Sat
# size              4
# Name: Dinner, dtype: object

# %%
df.iloc[[2, 4, 23]]
# Out:
#         total_bill   tip     sex smoker  day  size
# time
# Dinner       21.01  3.50    Male     No  Sun     3
# Dinner       24.59  3.61  Female     No  Sun     4
# Dinner       39.42  7.58    Male     No  Sat     4

# %%
df.iloc[22:27]
# Out:
#         total_bill   tip     sex smoker  day  size
# time
# Dinner       15.77  2.23  Female     No  Sat     2
# Dinner       39.42  7.58    Male     No  Sat     4
# Dinner       19.82  3.18    Male     No  Sat     2
# Dinner       17.81  2.34    Male     No  Sat     4
# Dinner       13.37  2.00    Male     No  Sat     2

# %% [markdown]
# Фильтрация в пандас такая же как в numpy (Про нампи мы поговорим с вами позднее)

# %%
df[df["sex"] == "Female"].head(7)
# Out:
#         total_bill   tip     sex smoker  day  size
# time
# Dinner       16.99  1.01  Female     No  Sun     2
# Dinner       24.59  3.61  Female     No  Sun     4
# Dinner       35.26  5.00  Female     No  Sun     4
# Dinner       14.83  3.02  Female     No  Sun     2
# Dinner       10.33  1.67  Female     No  Sun     3
# Dinner       16.97  3.50  Female     No  Sun     3
# Dinner       20.29  2.75  Female     No  Sat     2

# %% [markdown]
# Маски можно комбинировать, это удобно для ответа на запросы о данных. Например, мы хотим узнать как дают на чай некурящие девушки по субботы

# %%
le_masque = df["sex"] == "Female"
le_masque = le_masque & (df["day"] == "Sat")
le_masque &= df["smoker"] == "No"
df[le_masque].head()
# Out:
#         total_bill   tip     sex smoker  day  size
# time
# Dinner       20.29  2.75  Female     No  Sat     2
# Dinner       15.77  2.23  Female     No  Sat     2
# Dinner       19.65  3.00  Female     No  Sat     2
# Dinner       15.06  3.00  Female     No  Sat     2
# Dinner       20.69  2.45  Female     No  Sat     4

# %%
df[le_masque]["tip"].describe()
# Out:
# count    13.000000
# mean      2.724615
# std       0.961904
# min       1.000000
# 25%       2.230000
# 50%       2.750000
# 75%       3.000000
# max       4.670000
# Name: tip, dtype: float64

# %% [markdown]
# Уже можно придумывать желтушные заголовки вида «75% некурящих девушек по субботам дают на чай не больше 3 тугриков»

# %% [markdown]
# ## Pandas series

# %%
tea_list = ["чёрный", "зелёный", "травяной", "экспериментальный"]
pd.Series(tea_list) # то же самое что pd.Series(data=tea_list)
# Out:
# 0               чёрный
# 1              зелёный
# 2             травяной
# 3    экспериментальный
# dtype: object

# %%
list_of_ints  = [100,200,300]
pd.Series(list_of_ints)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
mixed_list = [42, False, "Дратути", None, [9, 8], {"name": "Алёнушка"}]
pd.Series(mixed_list)
# Out:
# 0                      42
# 1                   False
# 2                 Дратути
# 3                    None
# 4                  [9, 8]
# 5    {'name': 'Алёнушка'}
# dtype: object

# %% [markdown]
# Если вы инициализируете ваш Series объект из словарика, то ключи будут индексами

# %%
simple_dict = {"first_name": "Сергей", 
               "last_name": "Шнуров",
               "age": 45}
s = pd.Series(simple_dict)
display(s)
# Out:
# first_name    Сергей
# last_name     Шнуров
# age               45
# dtype: object

# %%
s['first_name']
# Out:
# 'Сергей'

# %% [markdown]
# Понятно, что у объекта Series есть всякие операторы, методы и тому подобное

# %%
print(dir(s))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '__xor__', '_accessors', '_accum_func', '_add_numeric_operations', '_agg_by_level', '_agg_examples_doc', '_agg_see_also_doc', '_align_frame', '_align_series', '_append', '_arith_method', '_as_manager', '_attrs', '_binop', '_can_hold_na', '_check_inplace_and_allows_duplicate_labels', '_check_inplace_setting', '_check_is_chained_assignment_possible', '_check_label_or_level_ambiguity', '_check_setitem_copy', '_clear_item_cache', '_clip_with_one_bound', '_clip_with_scalar', '_cmp_method', '_consolidate', '_consolidate_inplace', '_construct_axes_dict', '_construct_axes_from_arguments', '_construct_result', '_constructor', '_constructor_expanddim', '_convert', '_convert_dtypes', '_data', '_dir_additions', '_dir_deletions', '_drop_axis', '_drop_labels_or_levels', '_duplicated', '_find_valid_index', '_flags', '_get_axis', '_get_axis_name', '_get_axis_number', '_get_axis_resolvers', '_get_block_manager_axis', '_get_bool_data', '_get_cacher', '_get_cleaned_column_resolvers', '_get_index_resolvers', '_get_label_or_level_values', '_get_numeric_data', '_get_value', '_get_values', '_get_values_tuple', '_get_with', '_gotitem', '_hidden_attrs', '_indexed_same', '_info_axis', '_info_axis_name', '_info_axis_number', '_init_dict', '_init_mgr', '_inplace_method', '_internal_names', '_internal_names_set', '_is_cached', '_is_copy', '_is_label_or_level_reference', '_is_label_reference', '_is_level_reference', '_is_mixed_type', '_is_view', '_item_cache', '_ixs', '_logical_func', '_logical_method', '_map_values', '_maybe_update_cacher', '_memory_usage', '_metadata', '_mgr', '_min_count_stat_function', '_name', '_needs_reindex_multi', '_protect_consolidate', '_reduce', '_reindex_axes', '_reindex_indexer', '_reindex_multi', '_reindex_with_indexers', '_rename', '_replace_single', '_repr_data_resource_', '_repr_latex_', '_reset_cache', '_reset_cacher', '_set_as_cached', '_set_axis', '_set_axis_name', '_set_axis_nocheck', '_set_is_copy', '_set_labels', '_set_name', '_set_value', '_set_values', '_set_with', '_set_with_engine', '_slice', '_stat_axis', '_stat_axis_name', '_stat_axis_number', '_stat_function', '_stat_function_ddof', '_take', '_take_with_is_copy', '_typ', '_update_inplace', '_validate_dtype', '_values', '_where', 'abs', 'add', 'add_prefix', 'add_suffix', 'age', 'agg', 'aggregate', 'align', 'all', 'any', 'append', 'apply', 'argmax', 'argmin', 'argsort', 'array', 'asfreq', 'asof', 'astype', 'at', 'at_time', 'attrs', 'autocorr', 'axes', 'backfill', 'between', 'between_time', 'bfill', 'bool', 'clip', 'combine', 'combine_first', 'compare', 'convert_dtypes', 'copy', 'corr', 'count', 'cov', 'cummax', 'cummin', 'cumprod', 'cumsum', 'describe', 'diff', 'div', 'divide', 'divmod', 'dot', 'drop', 'drop_duplicates', 'droplevel', 'dropna', 'dtype', 'd ...

# %%
s.index
# Out:
# Index(['first_name', 'last_name', 'age'], dtype='object')

# %%
s.values
# Out:
# array(['Сергей', 'Шнуров', 45], dtype=object)

# %%
s = pd.Series(tea_list)
s.values
# Out:
# array(['чёрный', 'зелёный', 'травяной', 'экспериментальный'], dtype=object)

# %%
s =  pd.Series([2.03, 1.64, 1.87, 1.75])
s.sum()
# Out:
# 7.29

# %%
s.product()
# Out:
# 10.894806999999998

# %%
s.mean()
# Out:
# 1.8225

# %% [markdown]
# В отличие от dict, Series.index может быть неуникальным и его можно определять после

# %%
colors_list = ["red", "blue", "green", "yellow"]
numbers = ["one", "two", "three", "four"]

# pd.Series(colors_list, numbers) 
# pd.Series(colors_list, index=numbers) 
pd.Series(data=colors_list, index=numbers)
# Out:
# one         red
# two        blue
# three     green
# four     yellow
# dtype: object

# %%
s = pd.Series(data=colors_list, index=["one"]*3 + ["two"])
s
# Out:
# one       red
# one      blue
# one     green
# two    yellow
# dtype: object

# %%
s["one"]
# Out:
# one      red
# one     blue
# one    green
# dtype: object

# %%
s = pd.Series(colors_list)
s.is_unique
# Out:
# True

# %%
s.shape
# Out:
# (4,)

# %%
print(s.name)
s = pd.Series(colors_list, name="Блаблабла")
print(s.name)
print("---")
print(s)
# Out:
# None
# Блаблабла
# ---
# 0       red
# 1      blue
# 2     green
# 3    yellow
# Name: Блаблабла, dtype: object

# %%
s.sort_values()
# Out:
# 1      blue
# 2     green
# 0       red
# 3    yellow
# Name: Блаблабла, dtype: object

# %%
print(s.sort_values(ascending=False))
# Out:
# 3    yellow
# 0       red
# 2     green
# 1      blue
# Name: Блаблабла, dtype: object

# %%
print(s)
print("---")
s.sort_values(ascending=False, inplace=True)
print(s)
# Out:
# 0       red
# 1      blue
# 2     green
# 3    yellow
# Name: Блаблабла, dtype: object
# ---
# 3    yellow
# 0       red
# 2     green
# 1      blue
# Name: Блаблабла, dtype: object

# %%
s.sort_index()
# Out:
# 0       red
# 1      blue
# 2     green
# 3    yellow
# Name: Блаблабла, dtype: object

# %%
s.sort_index(ascending=False)
# Out:
# 3    yellow
# 2     green
# 1      blue
# 0       red
# Name: Блаблабла, dtype: object

# %%
s.sort_index(inplace=True)
s
# Out:
# 0       red
# 1      blue
# 2     green
# 3    yellow
# Name: Блаблабла, dtype: object

# %%
s = pd.Series(colors_list)
'red' in s.values
# Out:
# True

# %%
0 in s.index
# Out:
# True

# %%
s[0]
# Out:
# 'red'

# %%
s[[0, 2, 3]]
# Out:
# 0       red
# 2     green
# 3    yellow
# dtype: object

# %%
s.get(20, default="Непонятная штука")
# Out:
# 'Непонятная штука'

# %%
s = pd.Series([2.31, 1.2, 2.55, 1.7, 4.4444, 1.41])
s
# Out:
# 0    2.3100
# 1    1.2000
# 2    2.5500
# 3    1.7000
# 4    4.4444
# 5    1.4100
# dtype: float64

# %%
print(s.count(), len(s), s.sum(), s.mean(), s.product())
# Out:
# 6 6 13.6144 2.269066666666667 75.30339895847997

# %%
s.describe()
# Out:
# count    6.000000
# mean     2.269067
# std      1.184686
# min      1.200000
# 25%      1.482500
# 50%      2.005000
# 75%      2.490000
# max      4.444400
# dtype: float64

# %%
i = s.idxmax()
print("Максимум лежит по индексу %s и это %s" % (i, s.get(i)))
# Out:
# Максимум лежит по индексу 4 и это 4.4444

# %%
s = pd.Series(["Маша", "Паша", "Саша", "Маша", "Маша"])
s.value_counts()
# Out:
# Маша    3
# Паша    1
# Саша    1
# dtype: int64

# %%
s.value_counts().sum()
# Out:
# 5

# %%
s.count() == s.value_counts().sum()
# Out:
# True

# %%
s.value_counts(ascending=True)
# Out:
# Паша    1
# Саша    1
# Маша    3
# dtype: int64

# %%
Ну и есть ещё полезные штуки map/apply:
# Out:
#   Cell In[89], line 1
#     Ну и есть ещё полезные штуки map/apply:
#        ^
# SyntaxError: invalid syntax

# %%
s = pd.Series([2.31, 1.2, 2.55, 1.7, 4.4444, 1.41])
s
# Out:
# 0    2.3100
# 1    1.2000
# 2    2.5500
# 3    1.7000
# 4    4.4444
# 5    1.4100
# dtype: float64

# %%
def f(number):
    if number < 2.5:
        return "мало"
    return "МНОГО"

s.apply(f)
# Out:
# 0     мало
# 1     мало
# 2    МНОГО
# 3     мало
# 4    МНОГО
# 5     мало
# dtype: object

# %%
s.apply(lambda x: "%s штук" % x)
# Out:
# 0      2.31 штук
# 1       1.2 штук
# 2      2.55 штук
# 3       1.7 штук
# 4    4.4444 штук
# 5      1.41 штук
# dtype: object

# %%
s1 = pd.Series(data=["Маша", "Саша", "Паша", "Вася"])
s2 = pd.Series(
    data=[27, 12, 15, 70],
    index=["Маша", "Саша", "Паша", "Вася"])
s1.map(s2)
# Out:
# 0    27
# 1    12
# 2    15
# 3    70
# dtype: int64

# %%
s2_dict = s2.to_dict()

# %%
s2_dict["Паша"] = -13
s2_dict["Саша"] = 1000

# %%
s1.map(s2_dict)
# Out:
# 0      27
# 1    1000
# 2     -13
# 3      70
# dtype: int64

# %% [markdown]
# ## Графики

# %%
# %matplotlib inline
df[le_masque].plot();

# %%
import matplotlib.pyplot as plt
# display(df.corr())
plt.matshow(df.corr());
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13968\613482439.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(df.corr());

# %%
corr = df.corr()
corr
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13968\2438084875.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
import seaborn as sns
corr = df.corr()
sns.heatmap(
    corr, 
    xticklabels=corr.columns.values, 
    yticklabels=corr.columns.values);
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13968\3203793570.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %% [markdown]
# А ещё в seaborn есть функция загрузки "эталонных" датасетов. В частности, тот же iris. Ну и вообще в плане графиков для исследовательского анализа seaborn очень удобен

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df
# Out:
#         total_bill   tip     sex smoker   day  size
# time
# Dinner       16.99  1.01  Female     No   Sun     2
# Dinner       10.34  1.66    Male     No   Sun     3
# Dinner       21.01  3.50    Male     No   Sun     3
# Dinner       23.68  3.31    Male     No   Sun     2
# Dinner       24.59  3.61  Female     No   Sun     4
# ...            ...   ...     ...    ...   ...   ...
# Dinner       29.03  5.92    Male     No   Sat     3
# Dinner       27.18  2.00  Female    Yes   Sat     2
# Dinner       22.67  2.00    Male    Yes   Sat     2
# Dinner       17.82  1.75    Male     No   Sat     2
# Dinner       18.78  3.00  Female     No  Thur     2
#
# [244 rows x 6 columns]

# %%
g = sns.jointplot("sepal_length",
                  "sepal_width", 
                  data=iris,
                  kind="reg",
                  color="r", size=7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 g = sns.jointplot("sepal_length",
#       2                   "sepal_width",
#       3                   data=iris,
#       4                   kind="reg",
#       5                   color="r", size=7)
#
# TypeError: jointplot() got multiple values for argument 'data'

# %%
df
# Out:
#         total_bill   tip     sex smoker   day  size
# time
# Dinner       16.99  1.01  Female     No   Sun     2
# Dinner       10.34  1.66    Male     No   Sun     3
# Dinner       21.01  3.50    Male     No   Sun     3
# Dinner       23.68  3.31    Male     No   Sun     2
# Dinner       24.59  3.61  Female     No   Sun     4
# ...            ...   ...     ...    ...   ...   ...
# Dinner       29.03  5.92    Male     No   Sat     3
# Dinner       27.18  2.00  Female    Yes   Sat     2
# Dinner       22.67  2.00    Male    Yes   Sat     2
# Dinner       17.82  1.75    Male     No   Sat     2
# Dinner       18.78  3.00  Female     No  Thur     2
#
# [244 rows x 6 columns]

# %%
g = sns.jointplot("total_bill",
                  "tip", 
                  data=df,
                 
                  color="r", size=7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 g = sns.jointplot("total_bill",
#       2                   "tip",
#       3                   data=df,
#       4
#       5                   color="r", size=7)
#
# TypeError: jointplot() got multiple values for argument 'data'

# %%
g = sns.PairGrid(iris, diag_sharey=False)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.map_upper(plt.scatter)
g.map_diag(sns.kdeplot, lw=3);

# %% [markdown]
# Этих инструментов достаточно чтобы решить большинство задач про базовый анализ данных. Попробуйте применить эти инструменты для своих данных. Если у вас не хватает идей, ищите их в интернете, вступайте в сообщество Open Data Science (оно живёт в слаке) и не ограничивайтесь русскоязычными ресурсами.

# %% [markdown]
# ## Закрепим основы Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Создадим DF

# %%
dates = pd.date_range('20130101',periods=6)
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.517321 -0.045233 -1.381370 -1.614878
# 2013-01-02 -0.646261 -0.639794  0.744019 -0.365284
# 2013-01-03 -0.348733 -1.450690 -0.921784  0.585273
# 2013-01-04  0.268973  0.072697 -1.067324 -1.588653
# 2013-01-05  0.242287  0.300812  1.173059  1.889576
# 2013-01-06  1.260211 -0.467970 -0.698505 -1.220222

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# другой способ создания фрейма данных

# %%
df2 = pd.DataFrame(
    { 'A' : 1.,
      'B' : pd.Timestamp('20130102'),
      'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
      'D' : np.array([3] * 4,dtype='int32'),
      'E' : 'foo' })
df2
# Out:
#      A          B    C  D    E
# 0  1.0 2013-01-02  1.0  3  foo
# 1  1.0 2013-01-02  1.0  3  foo
# 2  1.0 2013-01-02  1.0  3  foo
# 3  1.0 2013-01-02  1.0  3  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.517321 -0.045233 -1.381370 -1.614878
# 2013-01-02 -0.646261 -0.639794  0.744019 -0.365284
# 2013-01-03 -0.348733 -1.450690 -0.921784  0.585273
# 2013-01-04  0.268973  0.072697 -1.067324 -1.588653
# 2013-01-05  0.242287  0.300812  1.173059  1.889576

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.51732068, -0.04523283, -1.38137032, -1.61487813],
#        [-0.64626098, -0.6397942 ,  0.74401878, -0.36528398],
#        [-0.34873257, -1.45068964, -0.92178408,  0.58527284],
#        [ 0.26897326,  0.07269749, -1.06732398, -1.58865312],
#        [ 0.24228667,  0.30081201,  1.1730587 ,  1.88957617],
#        [ 1.26021084, -0.46796965, -0.69850486, -1.22022182]])

# %%
# quick data summary
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.043193 -0.371696 -0.358651 -0.385698
# std    0.709207  0.632725  1.052882  1.398177
# min   -0.646261 -1.450690 -1.381370 -1.614878
# 25%   -0.475174 -0.596838 -1.030939 -1.496545
# 50%   -0.053223 -0.256601 -0.810144 -0.792753
# 75%    0.262302  0.043215  0.383388  0.347634
# max    1.260211  0.300812  1.173059  1.889576

# %%
Мы можем транспонировать индекс и столбцы.
# Out:
#   Cell In[118], line 1
#     Мы можем транспонировать индекс и столбцы.
#        ^
# SyntaxError: invalid syntax

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.517321   -0.646261   -0.348733    0.268973    0.242287    1.260211
# B   -0.045233   -0.639794   -1.450690    0.072697    0.300812   -0.467970
# C   -1.381370    0.744019   -0.921784   -1.067324    1.173059   -0.698505
# D   -1.614878   -0.365284    0.585273   -1.588653    1.889576   -1.220222

# %%
# axis 0 is index, axis 1 is columns
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.614878 -1.381370 -0.045233 -0.517321
# 2013-01-02 -0.365284  0.744019 -0.639794 -0.646261
# 2013-01-03  0.585273 -0.921784 -1.450690 -0.348733
# 2013-01-04 -1.588653 -1.067324  0.072697  0.268973
# 2013-01-05  1.889576  1.173059  0.300812  0.242287
# 2013-01-06 -1.220222 -0.698505 -0.467970  1.260211

# %%
# Можно сортировать по значениям
df.sort(columns='B')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[121], line 2
#       1 # Можно сортировать по значениям
# ----> 2 df.sort(columns='B')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sort() was deprecated for DataFrames in favor of either:

sort_values() to sort by column(s)
sort_index() to sort by the index

# %%
df.sort_values(by='A')
# Out:
#                    A         B         C         D
# 2013-01-02 -0.646261 -0.639794  0.744019 -0.365284
# 2013-01-01 -0.517321 -0.045233 -1.381370 -1.614878
# 2013-01-03 -0.348733 -1.450690 -0.921784  0.585273
# 2013-01-05  0.242287  0.300812  1.173059  1.889576
# 2013-01-04  0.268973  0.072697 -1.067324 -1.588653
# 2013-01-06  1.260211 -0.467970 -0.698505 -1.220222

# %% [markdown]
# ##### Будьте внимательны когда копипастите код! Код может устареть

# %%
df.sort_values('B')
# Out:
#                    A         B         C         D
# 2013-01-03 -0.348733 -1.450690 -0.921784  0.585273
# 2013-01-02 -0.646261 -0.639794  0.744019 -0.365284
# 2013-01-06  1.260211 -0.467970 -0.698505 -1.220222
# 2013-01-01 -0.517321 -0.045233 -1.381370 -1.614878
# 2013-01-04  0.268973  0.072697 -1.067324 -1.588653
# 2013-01-05  0.242287  0.300812  1.173059  1.889576

# %% [markdown]
# ###### Выборки

# %%
# выбераем столбец (и получаем серию)
df['A']
# Out:
# 2013-01-01   -0.517321
# 2013-01-02   -0.646261
# 2013-01-03   -0.348733
# 2013-01-04    0.268973
# 2013-01-05    0.242287
# 2013-01-06    1.260211
# Freq: D, Name: A, dtype: float64

# %%
df.A
# Out:
# 2013-01-01   -0.517321
# 2013-01-02   -0.646261
# 2013-01-03   -0.348733
# 2013-01-04    0.268973
# 2013-01-05    0.242287
# 2013-01-06    1.260211
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.517321 -0.045233 -1.381370 -1.614878
# 2013-01-02 -0.646261 -0.639794  0.744019 -0.365284
# 2013-01-03 -0.348733 -1.450690 -0.921784  0.585273

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.646261 -0.639794  0.744019 -0.365284
# 2013-01-03 -0.348733 -1.450690 -0.921784  0.585273
# 2013-01-04  0.268973  0.072697 -1.067324 -1.588653

# %% [markdown]
# Основное различие между loc и iloc заключается в следующем:
# loc основан на метках (label), что означает, что вы должны указать строки и столбцы на основе их меток строк и столбцов .
# iloc основан на целочисленной позиции, поэтому вы должны указать строки и столбцы по их целочисленным значениям позиции (целочисленная позиция на основе 0).
#
# Вот некоторые различия и сходства между loc и iloc:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# cross-section using a label
df.loc[dates[0]]
# Out:
# A   -0.517321
# B   -0.045233
# C   -1.381370
# D   -1.614878
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
# getting a scalar value
df.loc[dates[0], 'A']
# Out:
# -0.5173206840902834

# %%
# select via position
df.iloc[3]
# Out:
# A    0.268973
# B    0.072697
# C   -1.067324
# D   -1.588653
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[:5,:3]
# Out:
#                    A         B         C
# 2013-01-01 -0.517321 -0.045233 -1.381370
# 2013-01-02 -0.646261 -0.639794  0.744019
# 2013-01-03 -0.348733 -1.450690 -0.921784
# 2013-01-04  0.268973  0.072697 -1.067324
# 2013-01-05  0.242287  0.300812  1.173059

# %%
# column slicing
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01 -0.045233 -1.381370
# 2013-01-02 -0.639794  0.744019
# 2013-01-03 -1.450690 -0.921784
# 2013-01-04  0.072697 -1.067324
# 2013-01-05  0.300812  1.173059
# 2013-01-06 -0.467970 -0.698505

# %%
# get a value by index
df.iloc[1,1]
# Out:
# -0.6397941962241245

# %%
# boolean indexing
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-04  0.268973  0.072697 -1.067324 -1.588653
# 2013-01-05  0.242287  0.300812  1.173059  1.889576
# 2013-01-06  1.260211 -0.467970 -0.698505 -1.220222

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN       NaN       NaN
# 2013-01-02       NaN       NaN  0.744019       NaN
# 2013-01-03       NaN       NaN       NaN  0.585273
# 2013-01-04  0.268973  0.072697       NaN       NaN
# 2013-01-05  0.242287  0.300812  1.173059  1.889576
# 2013-01-06  1.260211       NaN       NaN       NaN

# %%
# фильтрация
df3 = df.copy()
df3['E'] = ['one', 'one', 'two', 'three', 'four', 'three']

# %%
df3
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.517321 -0.045233 -1.381370 -1.614878    one
# 2013-01-02 -0.646261 -0.639794  0.744019 -0.365284    one
# 2013-01-03 -0.348733 -1.450690 -0.921784  0.585273    two
# 2013-01-04  0.268973  0.072697 -1.067324 -1.588653  three
# 2013-01-05  0.242287  0.300812  1.173059  1.889576   four
# 2013-01-06  1.260211 -0.467970 -0.698505 -1.220222  three

# %%
df3[df3['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.348733 -1.450690 -0.921784  0.585273   two
# 2013-01-05  0.242287  0.300812  1.173059  1.889576  four

# %%
# setting examples
df.at[dates[0],'A'] = 0

df
# Out:
#                    A         B         C         D
# 2013-01-01  0.000000 -0.045233 -1.381370 -1.614878
# 2013-01-02 -0.646261 -0.639794  0.744019 -0.365284
# 2013-01-03 -0.348733 -1.450690 -0.921784  0.585273
# 2013-01-04  0.268973  0.072697 -1.067324 -1.588653
# 2013-01-05  0.242287  0.300812  1.173059  1.889576
# 2013-01-06  1.260211 -0.467970 -0.698505 -1.220222

# %%
# Доступ к одному значению для пары строка/столбец по целочисленной позиции.
#Подобно ``iloc``, в том, что оба обеспечивают поиск на основе целых чисел. Используем
#``iat``, если вам нужно получить или установить только одно значение в DataFrame
df.iat[0,1] = 0
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.000000  0.000000 -1.381370 -1.614878
# 2013-01-02 -0.646261 -0.639794  0.744019 -0.365284
# 2013-01-03 -0.348733 -1.450690 -0.921784  0.585273
# 2013-01-04  0.268973  0.072697 -1.067324 -1.588653
# 2013-01-05  0.242287  0.300812  1.173059  1.889576
# 2013-01-06  1.260211 -0.467970 -0.698505 -1.220222

# %%
df.loc[:, 'D'] = np.array([5] * len(df))
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13968\3998738297.py:1: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'D'] = np.array([5] * len(df))
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -1.381370  5
# 2013-01-02 -0.646261 -0.639794  0.744019  5
# 2013-01-03 -0.348733 -1.450690 -0.921784  5
# 2013-01-04  0.268973  0.072697 -1.067324  5
# 2013-01-05  0.242287  0.300812  1.173059  5
# 2013-01-06  1.260211 -0.467970 -0.698505  5

# %%
# работа с отсутствующими данными
df4 = df.reindex(index=dates[0:4],columns=list(df.columns) + ['E'])
df4
# Out:
#                    A         B         C  D   E
# 2013-01-01  0.000000  0.000000 -1.381370  5 NaN
# 2013-01-02 -0.646261 -0.639794  0.744019  5 NaN
# 2013-01-03 -0.348733 -1.450690 -0.921784  5 NaN
# 2013-01-04  0.268973  0.072697 -1.067324  5 NaN

# %%
df4.loc[dates[0]:dates[1],'E'] = 1

# %%
df4
# Out:
#                    A         B         C  D    E
# 2013-01-01  0.000000  0.000000 -1.381370  5  1.0
# 2013-01-02 -0.646261 -0.639794  0.744019  5  1.0
# 2013-01-03 -0.348733 -1.450690 -0.921784  5  NaN
# 2013-01-04  0.268973  0.072697 -1.067324  5  NaN

# %%
# удалить строки с отсутствующими данными
df4.dropna(how='any')
# Out:
#                    A         B         C  D    E
# 2013-01-01  0.000000  0.000000 -1.381370  5  1.0
# 2013-01-02 -0.646261 -0.639794  0.744019  5  1.0

# %%
# заполним недостающие данные
df4.fillna(value=5)
# Out:
#                    A         B         C  D    E
# 2013-01-01  0.000000  0.000000 -1.381370  5  1.0
# 2013-01-02 -0.646261 -0.639794  0.744019  5  1.0
# 2013-01-03 -0.348733 -1.450690 -0.921784  5  5.0
# 2013-01-04  0.268973  0.072697 -1.067324  5  5.0

# %%
# boolean маска для значений nan
pd.isnull(df4)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %% [markdown]
# ###### Operations

# %%
df.mean()
# Out:
# A    0.129413
# B   -0.364157
# C   -0.358651
# D    5.000000
# dtype: float64

# %%
# pivot the mean calculation
df.mean(1)
# Out:
# 2013-01-01    0.904657
# 2013-01-02    1.114491
# 2013-01-03    0.569698
# 2013-01-04    1.068587
# 2013-01-05    1.679039
# 2013-01-06    1.273434
# Freq: D, dtype: float64

# %%
# выравнивание объектов с разными размерами
s = pd.Series([1,3,5,np.nan,6,8],index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s,axis='index')
# Out:
#                    A         B         C    D
# 2013-01-01       NaN       NaN       NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN
# 2013-01-03 -1.348733 -2.450690 -1.921784  4.0
# 2013-01-04 -2.731027 -2.927303 -4.067324  2.0
# 2013-01-05 -4.757713 -4.699188 -3.826941  0.0
# 2013-01-06       NaN       NaN       NaN  NaN

# %%
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -1.381370  5
# 2013-01-02 -0.646261 -0.639794  0.744019  5
# 2013-01-03 -0.348733 -1.450690 -0.921784  5
# 2013-01-04  0.268973  0.072697 -1.067324  5
# 2013-01-05  0.242287  0.300812  1.173059  5
# 2013-01-06  1.260211 -0.467970 -0.698505  5

# %%
# Функция apply
df.apply(np.cumsum)
# Out:
#                    A         B         C   D
# 2013-01-01  0.000000  0.000000 -1.381370   5
# 2013-01-02 -0.646261 -0.639794 -0.637352  10
# 2013-01-03 -0.994994 -2.090484 -1.559136  15
# 2013-01-04 -0.726020 -2.017786 -2.626460  20
# 2013-01-05 -0.483734 -1.716974 -1.453401  25
# 2013-01-06  0.776477 -2.184944 -2.151906  30

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.906472
# B    1.751502
# C    2.554429
# D    0.000000
# dtype: float64

# %% [markdown]
# ###### Merging / Grouping

# %%
# Конкатенация
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  0.278870  0.292980  0.925663  0.262733
# 1  0.487128 -0.889894 -0.172915  1.908733
# 2 -1.797245 -1.126669 -1.227541 -0.465974
# 3  0.281030  1.872907 -0.659895  1.258041
# 4  0.085408 -1.240389  0.284651  1.840944
# 5  0.014699  0.405932  1.426266 -0.223936
# 6 -0.787913  0.794025 -1.315842  0.594727
# 7 -1.088680  0.206108  0.322090 -0.931369
# 8  0.942227  0.346891  1.157860 -0.308115
# 9  0.097805  1.743518 -0.432813  0.537444

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.278870  0.292980  0.925663  0.262733
# 1  0.487128 -0.889894 -0.172915  1.908733
# 2 -1.797245 -1.126669 -1.227541 -0.465974
# 3  0.281030  1.872907 -0.659895  1.258041
# 4  0.085408 -1.240389  0.284651  1.840944
# 5  0.014699  0.405932  1.426266 -0.223936
# 6 -0.787913  0.794025 -1.315842  0.594727
# 7 -1.088680  0.206108  0.322090 -0.931369
# 8  0.942227  0.346891  1.157860 -0.308115
# 9  0.097805  1.743518 -0.432813  0.537444

# %%
# SQL-style join
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
s = df.iloc[3]

# %%
df
# Out:
#           A         B         C         D
# 0 -1.573267  0.772079  1.594697 -1.405048
# 1 -0.794624  0.862067 -0.281804  0.710209
# 2 -1.366174  0.867851  1.575773 -0.296819
# 3 -1.189573  0.228364 -1.471117 -0.776419
# 4 -1.343383  0.968950 -3.436646  1.399141
# 5  0.948116 -0.278502 -0.370250 -2.234100
# 6  1.296908  1.093276  1.226746  1.468987
# 7  0.414695  0.928459 -0.165072 -0.850482

# %%
s
# Out:
# A   -1.189573
# B    0.228364
# C   -1.471117
# D   -0.776419
# Name: 3, dtype: float64

# %%
df.append(s, ignore_index=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13968\4011806271.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(s, ignore_index=True)
#           A         B         C         D
# 0 -1.573267  0.772079  1.594697 -1.405048
# 1 -0.794624  0.862067 -0.281804  0.710209
# 2 -1.366174  0.867851  1.575773 -0.296819
# 3 -1.189573  0.228364 -1.471117 -0.776419
# 4 -1.343383  0.968950 -3.436646  1.399141
# 5  0.948116 -0.278502 -0.370250 -2.234100
# 6  1.296908  1.093276  1.226746  1.468987
# 7  0.414695  0.928459 -0.165072 -0.850482
# 8 -1.189573  0.228364 -1.471117 -0.776419

# %%
df = pd.DataFrame(
    { 'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
      'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
      'C' : np.random.randn(8),
      'D' : np.random.randn(8) })
df
# Out:
#      A      B         C         D
# 0  foo    one  0.752646 -0.315179
# 1  bar    one  1.298191 -0.607060
# 2  foo    two  0.987619  1.518394
# 3  bar  three  0.161552 -0.464997
# 4  foo    two  0.091511  1.583457
# 5  bar    two -0.183102 -0.178320
# 6  foo    one -0.703324 -0.560606
# 7  foo  three  0.499529  0.649127

# %%
# Группировка
df.groupby('A').sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13968\2897771778.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('A').sum()
#             C         D
# A
# bar  1.276642 -1.250377
# foo  1.627981  2.875192

# %%
# Группировка по нескольким столбцам
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    1.298191 -0.607060
#     three  0.161552 -0.464997
#     two   -0.183102 -0.178320
# foo one    0.049322 -0.875785
#     three  0.499529  0.649127
#     two    1.079129  3.101850

# %%
df = pd.DataFrame(
    { 'A' : ['one', 'one', 'two', 'three'] * 3,
      'B' : ['A', 'B', 'C'] * 4,
      'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
      'D' : np.random.randn(12),
      'E' : np.random.randn(12)} )
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.851033  0.546189
# 1     one  B  foo  0.353651  0.359654
# 2     two  C  foo  0.330586  1.393629
# 3   three  A  bar  0.205413 -1.705548
# 4     one  B  bar  0.895959 -0.970223
# 5     one  C  bar -0.329128 -0.030410
# 6     two  A  foo  0.032166  1.878764
# 7   three  B  foo  0.417817  0.244048
# 8     one  C  foo -0.903975 -1.143942
# 9     one  A  bar -0.757350 -1.079082
# 10    two  B  bar -0.107744 -0.446453
# 11  three  C  bar  0.012233  1.950595

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.757350  0.851033
#       B  0.895959  0.353651
#       C -0.329128 -0.903975
# three A  0.205413       NaN
#       B       NaN  0.417817
#       C  0.012233       NaN
# two   A       NaN  0.032166
#       B -0.107744       NaN
#       C       NaN  0.330586

# %% [markdown]
# https://towardsdatascience.com/a-comparison-of-groupby-and-pivot-in-pythons-pandas-module-527909e78d6b

# %% [markdown]
# ###### Plotting

# %%
# time series plot
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
# plot with a data frame
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# ###### Input / Output

# %%
# Запиись в csc
df.to_csv('foo.csv', index=False)

# %%
# Чтение нового файла
path = r'foo.csv'
newDf = pd.read_csv(path)
newDf.head()
# Out:
#           A         B         C         D
# 0 -0.312255 -2.516038 -2.119069 -0.019078
# 1 -1.498313 -3.861599 -1.692907 -0.782349
# 2 -2.318111 -4.307247 -2.786576 -2.177471
# 3 -1.992114 -4.384507 -2.447891 -1.587200
# 4 -0.766387 -4.729125 -2.149039 -1.050583

# %%
# Уадление через знакомую вам уже библиотеку
import os
os.remove(path)

# %%
df
# Out:
#                    A         B          C          D
# 2000-01-01 -0.312255 -2.516038  -2.119069  -0.019078
# 2000-01-02 -1.498313 -3.861599  -1.692907  -0.782349
# 2000-01-03 -2.318111 -4.307247  -2.786576  -2.177471
# 2000-01-04 -1.992114 -4.384507  -2.447891  -1.587200
# 2000-01-05 -0.766387 -4.729125  -2.149039  -1.050583
# ...              ...       ...        ...        ...
# 2002-09-22 -7.447415  3.696768 -13.734584 -15.797483
# 2002-09-23 -7.987416  5.378581 -13.681878 -15.729125
# 2002-09-24 -8.570231  5.416169 -12.057923 -15.466944
# 2002-09-25 -8.361877  6.307782 -13.110383 -16.447599
# 2002-09-26 -8.582915  6.872548 -13.931401 -14.697946
#
# [1000 rows x 4 columns]

# %%
# Тоже самое мы можем сделать через Эксель
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %%
newDf2 = pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
newDf2.head()
# Out:
#   Unnamed: 0         A         B         C         D
# 0 2000-01-01 -0.312255 -2.516038 -2.119069 -0.019078
# 1 2000-01-02 -1.498313 -3.861599 -1.692907 -0.782349
# 2 2000-01-03 -2.318111 -4.307247 -2.786576 -2.177471
# 3 2000-01-04 -1.992114 -4.384507 -2.447891 -1.587200
# 4 2000-01-05 -0.766387 -4.729125 -2.149039 -1.050583

# %% [markdown]
# ###### Вкусности

# %%
from IPython.display import HTML, SVG, YouTubeVideo

# %%
HTML('''
<table style="border: 2px solid black;">
''' +
     ''.join(['<tr>' +
              ''.join([f'<td>{row},{col}</td>'
                       for col in range(5)]) +
              '</tr>' for row in range(5)]) +
     '''
</table>
''')
# Out:
# <table style="border: 2px solid black;">
# <tr><td>0,0</td><td>0,1</td><td>0,2</td><td>0,3</td><td>0,4</td></tr><tr><td>1,0</td><td>1,1</td><td>1,2</td><td>1,3</td><td>1,4</td></tr><tr><td>2,0</td><td>2,1</td><td>2,2</td><td>2,3</td><td>2,4</td></tr><tr><td>3,0</td><td>3,1</td><td>3,2</td><td>3,3</td><td>3,4</td></tr><tr><td>4,0</td><td>4,1</td><td>4,2</td><td>4,3</td><td>4,4</td></tr>
# </table>

# %%
SVG('''<svg width="600" height="80">''' +
    ''.join([f'''<circle
              cx="{(30 + 3*i) * (10 - i)}"
              cy="30"
              r="{3. * float(i)}"
              fill="red"
              stroke-width="2"
              stroke="black">
        </circle>''' for i in range(10)]) +
    '''</svg>''')

# %%
YouTubeVideo('VQBZ2MqWBZI')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = ("https://raw.githubusercontent.com/"
       "ipython-books/cookbook-2nd-data/"
       "master/bikes.csv")

# %%
df = pd.read_csv(url, index_col='Date',
                 parse_dates=True, dayfirst=True)

# %%
df.head(2)
# Out:
#            Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# Date
# 2013-01-01      00:00       0    0      1      0     6        0        1
# 2013-01-02      00:00      69    0     13      0    18        0        2
#
#             Totem_Laurier
# Date
# 2013-01-01              0
# 2013-01-02              0

# %%
df[['Berri1', 'PierDup']].plot(figsize=(10, 6),
                               style=['-', '--'],
                               lw=2)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_week = df.groupby(df.index.weekday).sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13968\3221179638.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_week = df.groupby(df.index.weekday).sum()

# %%
df_week
# Out:
#       Berri1    CSC  Mais1   Mais2   Parc  PierDup  Rachel1  Totem_Laurier
# Date
# 0     106826  51646  68087  129982  69767    44500   119211          72883
# 1     117244  54656  76974  141217  74299    40679   123533          76559
# 2     120434  59604  79033  145860  80437    42564   125173          79501
# 3     115193  52340  76273  141424  73668    36349   120684          74540
# 4     105701  44252  71605  127526  64385    36850   118556          71426
# 5      75754  27226  45947   79743  35544    46149    97143          56438
# 6      74873  29181  40812   75746  37620    53812   100735          53798

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
df_week.plot(style='-o', lw=3, ax=ax)
ax.set_xlabel('Weekday')
# We replace the labels 0, 1, 2... by the weekday
# names.
ax.set_xticklabels(
    ('Monday,Tuesday,Wednesday,Thursday,'
     'Friday,Saturday,Sunday').split(','))
ax.set_ylim(0)  # Set the bottom axis to 0.
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13968\4269678902.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# (0.0, 151791.7)

# %%
from ipywidgets import interact

@interact
def plot(n=(1, 30)):
    fig, ax = plt.subplots(1, 1, figsize=(10, 8))
    df['Berri1'].rolling(window=n).mean().plot(ax=ax)
    ax.set_ylim(0, 7000)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 from ipywidgets import interact
#       3 @interact
#       4 def plot(n=(1, 30)):
#       5     fig, ax = plt.subplots(1, 1, figsize=(10, 8))
#
# ModuleNotFoundError: No module named 'ipywidgets'

# %% [markdown]
# # ДЗ

# %% [markdown]
# ###### Задача 1 Связанные списки

# %% [markdown]
# Напишите функцию (пусть онабудет называться reverse_linked_list), которая разворачивает связный список. На вход она принимает головную ноду, а на выход отдаёт хвостовую ноду исходного списка, но только теперь если попробовать пройтись по ней, она будет новой головной. С функцией из примера выше,

# %%
class Node(object):
    def __init__(self, value=None, next_node=None):
        self.value = value
        self.next = next_node

    def __str__(self):
        return f"[Node with value {self.value}]"


def print_linked_list(head):
    cur = head
    while cur is not None:
        print(cur)
        cur = cur.next

def reverse_linked_list(head):
    cur = head
    curThis = None
    while cur is not None:
        curNext = cur.next
        cur.next = curThis
        curThis = cur 
        cur = curNext
    return curThis

h, a, b, c, d = Node(1), Node(2), Node(3), Node("Внезапно"), Node(5)

h.next = a
a.next = b
b.next = c
c.next = d

print_linked_list(h)
h = reverse_linked_list(h)
print("---")
print_linked_list(h)
# Out:
# [Node with value 1]
# [Node with value 2]
# [Node with value 3]
# [Node with value Внезапно]
# [Node with value 5]
# ---
# [Node with value 5]
# [Node with value Внезапно]
# [Node with value 3]
# [Node with value 2]
# [Node with value 1]

# %% [markdown]
# Напечатает

# %%
[Node with value 1]
[Node with value 2]
[Node with value 3]
[Node with value Внезапно]
[Node with value 5]
---
[Node with value 5]
[Node with value Внезапно]
[Node with value 3]
[Node with value 2]
[Node with value 1]
# Out:
#   Cell In[193], line 1
#     [Node with value 1]
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Подсказка: вам понадобится "вспомогательная нода", куда вы будете переворачивать список. Можете написать вспомотаельную функцию которая "переворачивает ноду".

# %% [markdown]
# ###### Задача 2 Пузырьки

# %% [markdown]
# Сортировкой пузырьком это один из самых простейших алгоритмов сортировки, который можно придумать. В базовом виде он подразумеват вложенный цикл и реализуется как-то так

# %%
l = [2, 4, 1, 1, 2, 0]

for i in range(len(l)):
    for j in range(i, len(l)):
        if l[i] > l[j]:
            l[i], l[j] = l[j], l[i]

print(l)

class Node(object):
    def __init__(self, value=None, next_node=None):
        self.value = value
        self.next = next_node

    def __str__(self):
        return f"[Node with value {self.value}]"


def print_linked_list(head):
    cur = head
    while cur is not None:
        print(cur)
        cur = cur.next

h, a, b, c, d, e = Node(2), Node(4), Node(1), Node(1), Node(2), Node(0)

h.next = a
a.next = b
b.next = c
c.next = d
d.next = e

def sortNodes(head):
    cur = head
    curNext = cur.next
    i = 0
    while cur is not None and curNext is not None:
        if head.value > curNext.value:
            head.value, curNext.value = curNext.value, head.value
            i += 1
        cur = cur.next
        curNext = cur.next
    if i != 0 and head.next is not None:
        sortNodes(head.next)
print("Не отсортированный")
print_linked_list(h)

sortNodes(h)
print("Отсортированный")
print_linked_list(h)
# Out:
# [0, 1, 1, 2, 2, 4]
# Не отсортиванный
# [Node with value 2]
# [Node with value 4]
# [Node with value 1]
# [Node with value 1]
# [Node with value 2]
# [Node with value 0]
# Отсортиванный
# [Node with value 0]
# [Node with value 1]
# [Node with value 1]
# [Node with value 2]
# [Node with value 2]
# [Node with value 4]

# %% [markdown]
# Вам предлагается написать функцию, которая будет на вход получать голову несортированного связного списка, а на выход возвращать голову отсортированного.

# %% [markdown]
# Подсказка: так как в задании ничего не сказано про то, как должна вести себя функция, можете считать что можно просто менять значения, которые лежат в нодах, без замены их указателей. Или можете написать вспомогательную функцию, которая будет менять две ноды местами.

# %% [markdown]
# Эта задачка вполне может показаться вам запутанной и сложной. Но я советую всё равно её решить.

# %% [markdown]
# Ну ладно. В общем, такого рода задачки это типичные задачки которые стоит порешать, если вы серьёзно хотите примерить на себя шляпу программиста. Там помимо таких конструкций как вот эти вот связные списки будет ещё много чего другого интересно, например бинарные деревья, куча и хэш-таблицы (и много чего другого). Решение задачек на обработку таких структур доставляет своё изощрённое удовольствие. Не отказываете себе в нём // DA

# %% [markdown]
# ###### Задача 3 Pandas

# %% [markdown]
# 1) Выясните, сколько в среднем выходи полный счёт по пятницам на ланч у курящих мужчин (датасет tips)

# %%
df5 = pd.read_csv('data/tips.csv')
df5.loc[(df5["sex"]=="Male") & (df5["smoker"]=="Yes") & (df5["day"]=="Fri")]["total_bill"].mean()
# Out:
# 20.4525

# %% [markdown]
# 2) Загрузите iris и посмотрите разбросы по всем числовым значениям для всех трёх классов цветов (датасет iris)

# %%
iris = pd.read_csv('data/iris.csv')
uniqueNames = iris["Name"].unique()

print(uniqueNames[0])
iris[iris["Name"] == uniqueNames[0]].describe()
# Out:
# Iris-setosa
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count     50.00000   50.000000    50.000000    50.00000
# mean       5.00600    3.418000     1.464000     0.24400
# std        0.35249    0.381024     0.173511     0.10721
# min        4.30000    2.300000     1.000000     0.10000
# 25%        4.80000    3.125000     1.400000     0.20000
# 50%        5.00000    3.400000     1.500000     0.20000
# 75%        5.20000    3.675000     1.575000     0.30000
# max        5.80000    4.400000     1.900000     0.60000

# %%
print(uniqueNames[1])
iris[iris["Name"] == uniqueNames[1]].describe()
# Out:
# Iris-versicolor
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count    50.000000   50.000000    50.000000   50.000000
# mean      5.936000    2.770000     4.260000    1.326000
# std       0.516171    0.313798     0.469911    0.197753
# min       4.900000    2.000000     3.000000    1.000000
# 25%       5.600000    2.525000     4.000000    1.200000
# 50%       5.900000    2.800000     4.350000    1.300000
# 75%       6.300000    3.000000     4.600000    1.500000
# max       7.000000    3.400000     5.100000    1.800000

# %%
print(uniqueNames[2])
iris[iris["Name"] == uniqueNames[2]].describe()
# Out:
# Iris-virginica
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count     50.00000   50.000000    50.000000    50.00000
# mean       6.58800    2.974000     5.552000     2.02600
# std        0.63588    0.322497     0.551895     0.27465
# min        4.90000    2.200000     4.500000     1.40000
# 25%        6.22500    2.800000     5.100000     1.80000
# 50%        6.50000    3.000000     5.550000     2.00000
# 75%        6.90000    3.175000     5.875000     2.30000
# max        7.90000    3.800000     6.900000     2.50000

# %% [markdown]
# 3) Создайте новый столбец с плотностью населения. Переименуйте названия первого и третьего столбца на русский язык

# %%
df = pd.DataFrame({
     'country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
     'population': [17.04, 143.5, 9.5, 45.5],
     'square': [2724902, 17125191, 207600, 603628]
 })
df['density'] = df['population']/df['square']

# %%
df
# Out:
#       country  population    square   density
# 0  Kazakhstan       17.04   2724902  0.000006
# 1      Russia      143.50  17125191  0.000008
# 2     Belarus        9.50    207600  0.000046
# 3     Ukraine       45.50    603628  0.000075

# %%
df.rename(columns = {'country':'страна', 'square':'площадь'}, inplace = True )
df
# Out:
#        страна  population   площадь   density
# 0  Kazakhstan       17.04   2724902  0.000006
# 1      Russia      143.50  17125191  0.000008
# 2     Belarus        9.50    207600  0.000046
# 3     Ukraine       45.50    603628  0.000075
